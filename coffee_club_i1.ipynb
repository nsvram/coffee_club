# %%
import warnings
import datetime
import warnings
import json
import pandas as pd
import time
import csv
import xlrd
import glob
import os
from datetime import datetime

# Visualize
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# Google maps
import gmaps

import googlemaps
import json
import os
from pandas.io.json import json_normalize
warnings.filterwarnings("ignore")
sns.set(style='darkgrid')

# %% [markdown]
# ## Data Processing

# %% [markdown]
# ! head /home/jovyan/.jupyter/jupyter_notebook_config.json

# %%
pd_coffee_survay = pd.read_excel("data/all_together.xlsx", ignore_index=True)
pd_coffee_survay["shop_name"],pd_coffee_survay["shop_address"]  = pd_coffee_survay["Address"].str.split("|",1).str

rating_mapping = {
      "Very Bad": -2,
      "Bad":-1,
      "Neutral": 0,
      "Good": 1, 
      "Very Good": 2
      }

pd_coffee_survay.columns = ['Image', 'Address', 'News_email', 'Coffee_ordered',
       'Taste_Quantity', 'Price', 'Service_Speed',
       'Atmosphere_Friendliness', 'Walking_Distance', 'Comments',
       'Date', 'Time_Taken', 'Country_Code', 'Region_Code', 'First_Name',
       'Last_Name', 'Email', 'Custom_Field', 'Participant_code',
       'Completed', 'External_ID',"shop_name", 'shop_address']
pd_coffee_survay_1 = pd_coffee_survay.replace({"Taste_Quantity":rating_mapping})\
    .replace({"Price":rating_mapping})\
    .replace({"Service_Speed":rating_mapping})\
    .replace({"Atmosphere_Friendliness":rating_mapping})\
    .replace({"Walking_Distance":rating_mapping}).dropna(how='all')
#print(pd_coffee_survay_1.columns)
print(pd_coffee_survay_1.shape)
pd_coffee_survay_1.head()
# Out:
# (99, 23)
#                                                Image  \
# 0  1. https://userfiles-fos.s3.amazonaws.com/1817...
# 1  1. https://userfiles-fos.s3.amazonaws.com/1817...
# 2  1. https://userfiles-fos.s3.amazonaws.com/1817...
# 3  1. https://userfiles-fos.s3.amazonaws.com/1817...
# 4  1. https://userfiles-fos.s3.amazonaws.com/1817...
#
#                                        Address  \
# 0   CJs Central|13 Eddy Ave Haymarket NSW 2000
# 1   CJs Central|13 Eddy Ave Haymarket NSW 2000
# 2   CJs Central|13 Eddy Ave Haymarket NSW 2000
# 3   CJs Central|13 Eddy Ave Haymarket NSW 2000
# 4   CJs Central|13 Eddy Ave Haymarket NSW 2000
#
#                            News_email                         Coffee_ordered  \
# 0  venkatram.sampathkumar@news.com.au                             Flat white
# 1            mannix.young@news.com.au                             Cappuccino
# 2               gao.jiang@news.com.au  Long black, Short black and Macchiato
# 3     worakorn.chaichakan@news.com.au                   Mocha, Hot chocolate
# 4              hai.nguyen@news.com.au                                  Latte
#
#    Taste_Quantity  Price  Service_Speed  Atmosphere_Friendliness  \
# 0             1.0    1.0            1.0                      0.0
# 1             1.0    2.0            1.0                      2.0
# 2             1.0    2.0            1.0                      1.0
# 3             1.0    1.0            1.0                      0.0
# 4             1.0    2.0            2.0                      0.0
#
#    Walking_Distance Comments               ...               Region_Code  \
# 0               0.0      NaN               ...                     NSW
# 1               1.0      NaN               ...                     NSW
# 2              -1.0      NaN               ...                     NSW
# 3               0.0      NaN               ...                     NSW
# 4               0.0      NaN               ...                     NSW
#
#    First_Name Last_Name Email  Custom_Field  Participant_code  Completed  \
# 0         NaN       NaN   NaN           NaN               NaN        1.0
# 1         NaN       NaN   NaN           NaN               NaN        1.0
# 2         NaN       NaN   NaN           NaN               NaN        1.0
# 3         NaN       NaN   NaN           NaN               NaN        1.0
# 4         NaN       NaN   NaN           NaN               NaN        1.0
#
#    External_ID     shop_name                    shop_address
# 0          NaN   CJs Central  13 Eddy Ave Haymarket NSW 2000
# 1          NaN   CJs Central  13 Eddy Ave Haymarket NSW 2000
# 2          NaN   CJs Central  13 Eddy Ave Haymarket NSW 2000
# 3          NaN   CJs Central  13 Eddy Ave Haymarket NSW 2000
# 4          NaN   CJs Central  13 Eddy Ave Haymarket NSW 2000
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Data Validation

# %%
a = pd_coffee_survay_1[['Region_Code','Address','News_email']].groupby(['Address','News_email']).agg(['count']).reset_index()
a.columns = ['Region_Code', 'News_email', 'Counts']
a[(a.Counts!=1)]
# Out:
# Empty DataFrame
# Columns: [Region_Code, News_email, Counts]
# Index: []

# %%
df_rating = pd_coffee_survay_1[['shop_name', 'shop_address',  'Taste_Quantity','Price','Service_Speed', 'Atmosphere_Friendliness', 'Walking_Distance']].groupby(['shop_name','shop_address']).agg(['mean'])
df_rating.columns = ['Taste_Quantity','Price','Service_Speed', 'Atmosphere_Friendliness', 'Walking_Distance']
df_rating.sort_values("Price")
df_plot = df_rating.reset_index()
df_plot["Score"] = df_plot.sum(axis=1)
df_plot
# Out:
#                                shop_name  \
# 0                            CJs Central
# 1                                 Frothy
# 2          ​The Reformatory Caffeine Lab
# 3                       Cafe And Cucina
# 4                Camys Chargrill Chicken
# 5                             Citta Cafe
# 6   Di Bella Coffee Roasting Warehouse​
# 7                          Kippax Coffee
# 8                       Lion corner Cafe
# 9                       News corp Coffee
# 10                      Orto Trading Co.
# 11            Ouroboros Wholefoods Cafe
# 12                          Point Blank
# 13                           Presse Cafe
# 14                               Saltie
# 15                        Sample Coffee
# 16                           Sienna Cafe
# 17                  Single O Surry Hills
# 18                         The Lab Cafe
#
#                                          shop_address  Taste_Quantity  \
# 0                      13 Eddy Ave Haymarket NSW 2000        1.000000
# 1               441 Elizabeth St Surry Hills NSW 2012        0.833333
# 2    ​Address: 17-51 Foveaux St, Surry Hills NSW 2...        0.800000
# 3               24 Cooper St, Surry Hills NSW 2010​​​        1.333333
# 4                 14 Foveaux St, Surry Hills NSW 2010        0.400000
# 5                     44 Holt St Surry Hills NSW 2010        1.333333
# 6                   50 Holt St, Surry Hills NSW 2010​        1.000000
# 7               8/24 Kippax St Surry Hills NSW 2010​​        0.333333
# 8                   69 Cooper St Surry Hills NSW 2010        0.800000
# 9                     2 Holt St Surry Hills NSW 2010​        0.500000
# 10              38 Waterloo St, Surry Hills NSW 2010​        1.000000
# 11   118 Devonshire Street, Surry Hills NSW 2010, ...        0.600000
# 12          1/47-53 Cooper St, Surry Hills NSW 2010​​        1.250000
# 13              280 Elizabeth St Surry Hills NSW 2010        0.600000
# 14            80 Devonshire St, Surry Hills NSW 2010​        0.400000
# 15        1a/118 Devonshire St, Surry Hills NSW 2010​        0.600000
# 16             407 Elizabeth St Surry Hills NSW 2010​        0.666667
# 17           60-64 Reservoir St, Surry Hills NSW 2010        1.500000
# 18    level g/418A Elizabeth St, Surry Hills NSW 2010        0.800000
#
#        Price  Service_Speed  Atmosphere_Friendliness  Walking_Distance  \
# 0   1.600000       1.200000                 0.600000          0.000000
# 1   1.000000       0.500000                 1.333333          0.666667
# 2   0.800000       1.000000                 1.400000          0.600000
# 3   0.666667       1.000000                 0.833333          1.500000
# 4   1.000000       1.000000                 0.000000          0.800000
# 5   0.833333       1.166667                 1.333333          1.500000
# 6   0.833333       1.000000                 1.166667          1.166667
# 7   1.333333       0.166667                 0.666667          1.500000
# 8   1.000000       0.800000                 0.600000          1.200000
# 9   1.000000       0.833333                 0.666667          1.500000
# 10  1.000000       1.500000                 1.166667          0.833333
# 11  1.000000       1.200000                 1.000000          1.000000
# 12  0.750000       1.250000                 1.000000          1.250000
# 13  1.400000       1.200000                 0.600000          0.800000
# 14  0.600000      -1.000000                 0.200000          0.000000
# 15  0.000000       0.400000                 0.600000          0.600000
# 16  0.333333      -0.333333                 0.000000          0.333333
# 17  0.500000       0.750000                 1.250000          0.000000
# 18  1.000000       1.200000                 0.800000          0.400000
#
#        Score
# 0   4.400000
# 1   4.333333
# 2   4.600000
# 3   5.333333
# 4   3.200000
# 5   6.166667
# 6   5.166667
# 7   4.000000
# 8   4.400000
# 9   4.500000
# 10  5.500000
# 11  4.800000
# 12  5.500000
# 13  4.600000
# 14  0.200000
# 15  2.200000
# 16  1.000000
# 17  4.000000
# 18  4.200000

# %% [markdown]
# ## Analysis

# %%
# Total entires
len(pd_coffee_survay_1)
# Out:
# 99

# %%
# Coffee shops ordered by score - Best to worst
df_plot.sort_values("Score",ascending=False)[:10][["shop_name","shop_address","Score"]].sort_values("Score",ascending=True)[["shop_name","shop_address"]]
# Out:
#                                shop_name  \
# 8                       Lion corner Cafe
# 9                       News corp Coffee
# 2          ​The Reformatory Caffeine Lab
# 13                           Presse Cafe
# 11            Ouroboros Wholefoods Cafe
# 6   Di Bella Coffee Roasting Warehouse​
# 3                       Cafe And Cucina
# 10                      Orto Trading Co.
# 12                          Point Blank
# 5                             Citta Cafe
#
#                                          shop_address
# 8                   69 Cooper St Surry Hills NSW 2010
# 9                     2 Holt St Surry Hills NSW 2010​
# 2    ​Address: 17-51 Foveaux St, Surry Hills NSW 2...
# 13              280 Elizabeth St Surry Hills NSW 2010
# 11   118 Devonshire Street, Surry Hills NSW 2010, ...
# 6                   50 Holt St, Surry Hills NSW 2010​
# 3               24 Cooper St, Surry Hills NSW 2010​​​
# 10              38 Waterloo St, Surry Hills NSW 2010​
# 12          1/47-53 Cooper St, Surry Hills NSW 2010​​
# 5                     44 Holt St Surry Hills NSW 2010

# %% [markdown]
# # Visualize

# %% [markdown]
# ## Time series

# %%
pd_coffee_survay_1['to_Date'] = pd_coffee_survay_1['Date'].dt.date
df_timeseries = pd_coffee_survay_1[['to_Date','shop_name', 'Taste_Quantity','Price','Service_Speed', 'Atmosphere_Friendliness', 'Walking_Distance']].groupby(['to_Date']).agg(['mean'])
df_timeseries["Score"] = df_timeseries.sum(axis=1)
df_timeseries = df_timeseries.reset_index()
timeseries = df_timeseries[['to_Date','Score']]


plt.figure(figsize=(20,7))
x=timeseries['to_Date']
y=timeseries['Score']
plt.plot(x,y , color='green', marker='o', linestyle='dashed', linewidth=2, markersize=10)
plt
# Out:
# <module 'matplotlib.pyplot' from '/opt/conda/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ## Pie charts - Overall survay polled

# %%
my_data = pd_coffee_survay_1[['Address','News_email']].groupby(['News_email']).agg(['count'])
my_data = my_data.reset_index()
my_data.columns = ['News_email','Counts']
#my_data['Coffee_ordered']
#my_data['Counts']
fig1, ax1 = plt.subplots()
ax1.pie(my_data['Counts'], labels=my_data['News_email'], autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')
plt.show()

# %% [markdown]
# # Overall Coffee ordered

# %%
my_data = pd_coffee_survay_1[['Address','Coffee_ordered']].groupby(['Coffee_ordered']).agg(['count'])
my_data = my_data.reset_index()
my_data.columns = ['Coffee_ordered','Counts']
#my_data['Coffee_ordered']
#my_data['Counts']
fig1, ax1 = plt.subplots()
ax1.pie(my_data['Counts'], labels=my_data['Coffee_ordered'], autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')
plt.show()

# %% [markdown]
# # Numbers of polls per Coffee Shops

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='shop_name', \
              data=pd_coffee_survay_1, \
              order=pd_coffee_survay_1['shop_name'].value_counts().index, 
              palette=sns.color_palette("GnBu_d", 20))

plt.title("Count plot of Participants by Coffee Shops", fontsize=20)
plt.xlabel('Coffee Shops', fontsize=20)
plt.ylabel('Number of Participants', fontsize=20)
# Set the length of the bar chart
plt.xlim(len(pd_coffee_survay_1[['shop_name']].groupby(['shop_name']).count()),-1)
plt.xticks(rotation=70, fontsize=10)
plt.show()

# %% [markdown]
# ## Coffee shops based on the parameters - parallel_coordinates

# %%
df_plot.columns
# Out:
# Index(['shop_name', 'shop_address', 'Taste_Quantity', 'Price', 'Service_Speed',
#        'Atmosphere_Friendliness', 'Walking_Distance', 'Score'],
#       dtype='object')

# %%
df_plot.head(2)
# Out:
#       shop_name                           shop_address  Taste_Quantity  Price  \
# 0   CJs Central         13 Eddy Ave Haymarket NSW 2000        1.000000    1.6
# 1        Frothy  441 Elizabeth St Surry Hills NSW 2012        0.833333    1.0
#
#    Service_Speed  Atmosphere_Friendliness  Walking_Distance     Score
# 0            1.2                 0.600000          0.000000  4.400000
# 1            0.5                 1.333333          0.666667  4.333333

# %%
from pandas.tools.plotting import parallel_coordinates

plt.figure(figsize=(20,7))
parallel_coordinates(df_plot[['shop_name', 'Taste_Quantity', 'Price', 'Service_Speed','Atmosphere_Friendliness', 'Walking_Distance', 'Score']],"shop_name",colormap=plt.get_cmap("Set2"))
plt.xticks(rotation=50, fontsize=10)
plt.show()

# %% [markdown]
# ## Bar Charts

# %%
#df_plot.index = df_plot['shop_name']
#df_plot

# %%
df_plot['shop_name']
# Out:
# 0                              CJs Central
# 1                                   Frothy
# 2            ​The Reformatory Caffeine Lab
# 3                         Cafe And Cucina
# 4                  Camys Chargrill Chicken
# 5                               Citta Cafe
# 6     Di Bella Coffee Roasting Warehouse​
# 7                            Kippax Coffee
# 8                         Lion corner Cafe
# 9                         News corp Coffee
# 10                        Orto Trading Co.
# 11              Ouroboros Wholefoods Cafe
# 12                            Point Blank
# 13                             Presse Cafe
# 14                                 Saltie
# 15                          Sample Coffee
# 16                             Sienna Cafe
# 17                    Single O Surry Hills
# 18                           The Lab Cafe
# Name: shop_name, dtype: object

# %%
df_plot.plot.bar(x='shop_name', y='Score')

# %%
df_plot.plot.bar(x='shop_name',
                 y=['Score','Taste_Quantity','Price','Service_Speed', 'Atmosphere_Friendliness', 'Walking_Distance'],
                 figsize=(15,7), rot=60)

# %%
df_plot.plot.barh(x='shop_name',y='Score')

# %%
df_plot.plot.line(x='shop_name',y='Score')
plt.xticks(rotation=60, fontsize=10)
plt.show()

# %% [markdown]
# ## Detailed bar chart - Explains ratting based on overall score

# %%
df_plot.iloc[:,:6].plot(x='shop_name',kind='bar', stacked=True, figsize=(12,6), rot=65)
plt
# Out:
# <module 'matplotlib.pyplot' from '/opt/conda/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ## Top 10 coffee shops

# %%
df_plot.sort_values( "Score", ascending=False)[:10]
# Out:
#                                shop_name  \
# 5                             Citta Cafe
# 10                      Orto Trading Co.
# 12                          Point Blank
# 3                       Cafe And Cucina
# 6   Di Bella Coffee Roasting Warehouse​
# 11            Ouroboros Wholefoods Cafe
# 13                           Presse Cafe
# 2          ​The Reformatory Caffeine Lab
# 9                       News corp Coffee
# 8                       Lion corner Cafe
#
#                                          shop_address  Taste_Quantity  \
# 5                     44 Holt St Surry Hills NSW 2010        1.333333
# 10              38 Waterloo St, Surry Hills NSW 2010​        1.000000
# 12          1/47-53 Cooper St, Surry Hills NSW 2010​​        1.250000
# 3               24 Cooper St, Surry Hills NSW 2010​​​        1.333333
# 6                   50 Holt St, Surry Hills NSW 2010​        1.000000
# 11   118 Devonshire Street, Surry Hills NSW 2010, ...        0.600000
# 13              280 Elizabeth St Surry Hills NSW 2010        0.600000
# 2    ​Address: 17-51 Foveaux St, Surry Hills NSW 2...        0.800000
# 9                     2 Holt St Surry Hills NSW 2010​        0.500000
# 8                   69 Cooper St Surry Hills NSW 2010        0.800000
#
#        Price  Service_Speed  Atmosphere_Friendliness  Walking_Distance  \
# 5   0.833333       1.166667                 1.333333          1.500000
# 10  1.000000       1.500000                 1.166667          0.833333
# 12  0.750000       1.250000                 1.000000          1.250000
# 3   0.666667       1.000000                 0.833333          1.500000
# 6   0.833333       1.000000                 1.166667          1.166667
# 11  1.000000       1.200000                 1.000000          1.000000
# 13  1.400000       1.200000                 0.600000          0.800000
# 2   0.800000       1.000000                 1.400000          0.600000
# 9   1.000000       0.833333                 0.666667          1.500000
# 8   1.000000       0.800000                 0.600000          1.200000
#
#        Score
# 5   6.166667
# 10  5.500000
# 12  5.500000
# 3   5.333333
# 6   5.166667
# 11  4.800000
# 13  4.600000
# 2   4.600000
# 9   4.500000
# 8   4.400000

# %% [markdown]
# ## Geo spatial Analysis using Google Maps API

# %%
def f(x):
    return str(x[0]) + ' ' + str(x[1]) 

def get_google_walking_distance(row):
    start_lat_lng = "-33.8853242 151.2096684"
    directions_result = gmaps.directions(start_lat_lng, (row["lat"] ,row["lng"]),mode="walking")
    return str(directions_result[0]['legs'][0]['distance']['text']) 

def get_google_walking_duration(row):
    start_lat_lng = "-33.8853242 151.2096684"
    directions_result = gmaps.directions(start_lat_lng, (row["lat"] ,row["lng"]),mode="walking")
    return str(directions_result[0]['legs'][0]['duration']['text'])

# %%
# Get NewsCorp lat and lng
gmaps = googlemaps.Client(key='AIzaSyCiQ3LOYgzaGOPmfPkIs5hEsZa3srHB4Hc')
geocode_result = gmaps.geocode('2 holt street surry hills nsw 2010')
lat = geocode_result[0]["geometry"]["location"]['lat']
lng = geocode_result[0]["geometry"]["location"]['lng']

# %%
geocode_result[0]["geometry"]["location"]['lat'],geocode_result[0]["geometry"]["location"]['lng']
# Out:
# (-33.8853242, 151.2096684)

# %%
def get_lat_lng(addr):
    gmaps = googlemaps.Client(key='AIzaSyCiQ3LOYgzaGOPmfPkIs5hEsZa3srHB4Hc')
    geocode_result = gmaps.geocode(addr)
    return [geocode_result[0]["geometry"]["location"]['lat'], geocode_result[0]["geometry"]["location"]['lng']]

# %%
mylist=[]
for i in pd.unique(pd_coffee_survay_1[pd_coffee_survay_1['Address'].notnull()].Address):
    mylist.append([(i.split("|")[0].strip()), (i.split("|")[1].strip())] + get_lat_lng(i.split("|")[1].strip()))

# %%
df_coffe_shops = pd.DataFrame(mylist,columns=['shop_name','shop_address','lat','lng'])
df_coffe_shops.head()
# Out:
#                  shop_name                              shop_address  \
# 0              CJs Central            13 Eddy Ave Haymarket NSW 2000
# 1              Presse Cafe     280 Elizabeth St Surry Hills NSW 2010
# 2         Lion corner Cafe         69 Cooper St Surry Hills NSW 2010
# 3  Camys Chargrill Chicken       14 Foveaux St, Surry Hills NSW 2010
# 4     Single O Surry Hills  60-64 Reservoir St, Surry Hills NSW 2010
#
#          lat         lng
# 0 -33.883690  151.206005
# 1 -33.882197  151.209068
# 2 -33.886086  151.210449
# 3 -33.883775  151.209404
# 4 -33.881047  151.209658

# %%
df_geospatial = df_coffe_shops.join(df_plot, lsuffix='df_coffe_shops.shop_name', rsuffix='df_plot.shop_name')
df_geospatial.columns
# Out:
# Index(['shop_namedf_coffe_shops.shop_name',
#        'shop_addressdf_coffe_shops.shop_name', 'lat', 'lng',
#        'shop_namedf_plot.shop_name', 'shop_addressdf_plot.shop_name',
#        'Taste_Quantity', 'Price', 'Service_Speed', 'Atmosphere_Friendliness',
#        'Walking_Distance', 'Score'],
#       dtype='object')

# %%
df_geospatial.sort_values("Score",ascending=False)[:10]#[["shop_namedf_coffe_shops.shop_name", "shop_address"]]
#df_geospatial
# Out:
#       shop_namedf_coffe_shops.shop_name  \
# 5                      Orto Trading Co.
# 10                               Saltie
# 12                      Cafe And Cucina
# 3               Camys Chargrill Chicken
# 6             Ouroboros Wholefoods Cafe
# 11  Di Bella Coffee Roasting Warehouse​
# 13        ​The Reformatory Caffeine Lab
# 2                      Lion corner Cafe
# 9                         Sample Coffee
# 8                           Point Blank
#
#                  shop_addressdf_coffe_shops.shop_name        lat         lng  \
# 5               38 Waterloo St, Surry Hills NSW 2010​ -33.886819  151.210571
# 10            80 Devonshire St, Surry Hills NSW 2010​ -33.886015  151.207849
# 12              24 Cooper St, Surry Hills NSW 2010​​​ -33.885363  151.209074
# 3                 14 Foveaux St, Surry Hills NSW 2010 -33.883775  151.209404
# 6   118 Devonshire Street, Surry Hills NSW 2010, A... -33.886680  151.209190
# 11                  50 Holt St, Surry Hills NSW 2010​ -33.886480  151.209561
# 13  ​Address: 17-51 Foveaux St, Surry Hills NSW 2010​ -33.884088  151.209425
# 2                   69 Cooper St Surry Hills NSW 2010 -33.886086  151.210449
# 9         1a/118 Devonshire St, Surry Hills NSW 2010​ -33.886680  151.209190
# 8           1/47-53 Cooper St, Surry Hills NSW 2010​​ -33.885963  151.209726
#
#               shop_namedf_plot.shop_name  \
# 5                             Citta Cafe
# 10                      Orto Trading Co.
# 12                          Point Blank
# 3                       Cafe And Cucina
# 6   Di Bella Coffee Roasting Warehouse​
# 11            Ouroboros Wholefoods Cafe
# 13                           Presse Cafe
# 2          ​The Reformatory Caffeine Lab
# 9                       News corp Coffee
# 8                       Lion corner Cafe
#
#                         shop_addressdf_plot.shop_name  Taste_Quantity  \
# 5                     44 Holt St Surry Hills NSW 2010        1.333333
# 10              38 Waterloo St, Surry Hills NSW 2010​        1.000000
# 12          1/47-53 Cooper St, Surry Hills NSW 2010​​        1.250000
# 3               24 Cooper St, Surry Hills NSW 2010​​​        1.333333
# 6                   50 Holt St, Surry Hills NSW 2010​        1.000000
# 11   118 Devonshire Street, Surry Hills NSW 2010, ...        0.600000
# 13              280 Elizabeth St Surry Hills NSW 2010        0.600000
# 2    ​Address: 17-51 Foveaux St, Surry Hills NSW 2...        0.800000
# 9                     2 Holt St Surry Hills NSW 2010​        0.500000
# 8                   69 Cooper St Surry Hills NSW 2010        0.800000
#
#        Price  Service_Speed  Atmosphere_Friendliness  Walking_Distance  \
# 5   0.833333       1.166667                 1.333333          1.500000
# 10  1.000000       1.500000                 1.166667          0.833333
# 12  0.750000       1.250000                 1.000000          1.250000
# 3   0.666667       1.000000                 0.833333          1.500000
# 6   0.833333       1.000000                 1.166667          1.166667
# 11  1.000000       1.200000                 1.000000          1.000000
# 13  1.400000       1.200000                 0.600000          0.800000
# 2   0.800000       1.000000                 1.400000          0.600000
# 9   1.000000       0.833333                 0.666667          1.500000
# 8   1.000000       0.800000                 0.600000          1.200000
#
#        Score
# 5   6.166667
# 10  5.500000
# 12  5.500000
# 3   5.333333
# 6   5.166667
# 11  4.800000
# 13  4.600000
# 2   4.600000
# 9   4.500000
# 8   4.400000

# %%
import gmaps
gmaps.configure(api_key='AIzaSyCiQ3LOYgzaGOPmfPkIs5hEsZa3srHB4Hc') # Fill in with your API key
locations = df_geospatial[["lat","lng"]]
Score = df_geospatial["Score"]
shops_names=df_geospatial["shop_namedf_coffe_shops.shop_name"]

# %%
fig = gmaps.figure()
fig.add_layer(gmaps.WeightedHeatmap(locations=locations,weights=Score,point_radius = 10 ,max_intensity = 5))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
df_geospatial.columns
# Out:
# Index(['shop_namedf_coffe_shops.shop_name',
#        'shop_addressdf_coffe_shops.shop_name', 'lat', 'lng',
#        'shop_namedf_plot.shop_name', 'shop_addressdf_plot.shop_name',
#        'Taste_Quantity', 'Price', 'Service_Speed', 'Atmosphere_Friendliness',
#        'Walking_Distance', 'Score'],
#       dtype='object')

# %%
subset = df_geospatial[['lat','lng']]
tuples = [tuple(x) for x in subset.values]
info_box = df_geospatial['shop_addressdf_coffe_shops.shop_name' ]

marker = gmaps.marker_layer(locations=locations,label=shops_names,info_box_content=info_box)
drawing = gmaps.drawing_layer(features=[gmaps.Polygon(tuples,stroke_color='red', fill_color=(255, 0, 132))])

fig.add_layer(drawing)
fig.add_layer(marker)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
