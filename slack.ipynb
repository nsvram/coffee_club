# %%
! pip install slackclient
# Out:
# ...
#     100% |████████████████████████████████| 204kB 3.7MB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for slackclient ... done
#   Stored in directory: /home/jovyan/.cache/pip/wheels/9b/98/ba/f96daa1eefaf60cba7f95d087b2d86c5169127b3624142b586
# Successfully built slackclient
# ...

# %%
#! pip install slackclient

# %%
import os
from slackclient import SlackClient

# %%
sc = SlackClient("xoxp-3597524324-330219332868-399033752992-9fdb2ee03df29369a31259d81dc42eac")

# %%
sc.api_call(
  "chat.postMessage",
  channel="testingpython",
  text="Hello from Data Robo! :tada:",
  username = 'venkatram.sampathkumar'
)
# Out:
# {'ok': True,
#  'channel': 'CBRSA8GAH',
#  'ts': '1532328224.000160',
#  'message': {'text': 'Hello from Data Robo! :tada:',
#   'username': 'venkatram.sampathkumar',
#   'bot_id': 'BBR5MFEAD',
#   'type': 'message',
#   'subtype': 'bot_message',
#   'ts': '1532328224.000160'},
#  'headers': {'Content-Type': 'application/json; charset=utf-8',
#   'Content-Length': '185',
#   'Connection': 'keep-alive',
#   'Date': 'Mon, 23 Jul 2018 06:43:44 GMT',
#   'Server': 'Apache',
#   'Expires': 'Mon, 26 Jul 1997 05:00:00 GMT',
#   'X-Content-Type-Options': 'nosniff',
#   'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload',
#   'Referrer-Policy': 'no-referrer',
#   'Cache-Control': 'private, no-cache, no-store, must-revalidate',
#   'X-OAuth-Scopes': 'read,client,identify,post,apps',
#   'Pragma': 'no-cache',
#   'X-Accepted-OAuth-Scopes': 'chat:write:bot,post',
#   'X-XSS-Protection': '0',
#   'X-Slack-Req-Id': 'ce94e993-9f83-4415-82c1-5da933c018bd',
# ...

# %%
sc.api_call("channels.list")
# Out:
# {'ok': True,
#  'channels': [{'id': 'C6E505WLT',
#    'name': '1degree',
#    'is_channel': True,
#    'created': 1501111921,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'U03K8P7N1',
#    'name_normalized': '1degree',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': False,
#    'is_private': False,
#    'is_mpim': False,
#    'members': [],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '1degree site migration to openshift',
#     'creator': 'U03K8P7N1',
#     'last_set': 1501112032},
#    'previous_names': [],
#    'num_members': 2},
#   {'id': 'CAUJX4LT0',
#    'name': '2for1tuesdays',
#    'is_channel': True,
#    'created': 1526950483,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'U9KLY4W3D',
#    'name_normalized': '2for1tuesdays',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
# ...

# %%
with DAG('my_dag', start_date=datetime(2016, 1, 1)) as dag:
    (
        DummyOperator(task_id='dummy_1')
        >> BashOperator(
            task_id='bash_1',
            bash_command='echo "HELLO!"')
        >> PythonOperator(
            task_id='python_1',
# Out:
#   File "<ipython-input-3-e6b1d3490f2a>", line 9
#
#     ^
# SyntaxError: unexpected EOF while parsing
